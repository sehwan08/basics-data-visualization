# %% [markdown]
# ### Project 1 - Population Pyramid

# %% [markdown]
# ### 남자 데이터

# %%
import pandas as pd
df_m = pd.read_excel('201112_201112_연령별인구현황_월간.xlsx', skiprows=3, index_col='행정기관',
                    usecols='B, E:Y')
df_m
# Out:
# C:\devtools\python\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                 0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         1,198,629  1,218,866  1,635,253  1,882,958  1,688,523  1,811,906
# 서울특별시        217,099    213,296    284,211    346,341    337,208    425,224
# 부산광역시         67,561     69,275    100,418    129,556    123,139    127,645
# 대구광역시         53,691     59,382     86,060    103,540     93,449     85,681
# 인천광역시         68,511     67,688     90,598    108,523     98,356    102,165
# 광주광역시         37,452     40,844     57,241     62,773     50,772     52,316
# 대전광역시         38,302     40,402     53,450     61,306     54,648     55,649
# 울산광역시         29,624     29,199     41,539     50,177     42,080     40,104
# 경기도          321,179    325,500    414,592    451,409    385,905    415,444
# 강원도           32,577     35,954     49,205     54,452     52,414     48,907
# 충청북도          37,908     38,307     51,790     59,062     51,740     54,093
# 충청남도          53,382     52,083     67,481     72,666     63,864     72,590
# 전라북도          41,950     45,016     62,239     70,059     61,036     59,883
# 전라남도          41,502     42,763     61,184     68,467     57,846     56,639
# 경상북도          59,550     59,406     81,571     94,579     90,768     89,105
# 경상남도          83,483     83,188    112,232    127,302    107,591    108,904
# 제주특별자치도       14,858     16,563     21,442     22,746     17,707     17,557
#
#               30~34세     35~39세     40~44세     45~49세  ...     55~59세  \
# 행정기관                                                   ...
# 전국         2,053,846  2,157,764  2,341,732  2,176,857  ...  1,598,548
# 서울특별시        473,659    454,415    461,689    413,722  ...    332,974
# 부산광역시        138,435    134,969    148,270    145,936  ...    136,690
# 대구광역시         91,645    100,241    114,841    110,084  ...     80,598
# 인천광역시        117,371    122,844    132,406    130,257  ...     85,800
# 광주광역시         58,161     62,284     66,526     59,552  ...     37,628
# 대전광역시         61,025     65,560     70,718     63,155  ...     45,301
# 울산광역시         47,459     47,402     55,091     56,022  ...     36,400
# 경기도          500,699    555,001    600,130    544,270  ...    336,376
# 강원도           51,313     58,903     67,704     65,189  ...     55,067
# 충청북도          58,016     62,856     70,200     66,106  ...     50,734
# 충청남도          84,000     86,540     93,890     85,424  ...     64,615
# 전라북도          64,044     71,807     80,286     75,378  ...     59,417
# 전라남도          61,556     69,362     81,564     80,780  ...     61,419
# 경상북도          97,370    103,218    116,161    112,974  ...     93,558
# 경상남도         128,811    138,323    154,797    142,562  ...    105,378
# 제주특별자치도       20,282     24,039     27,459     25,446  ...     16,593
#
#               60~64세   65~69세   70~74세   75~79세   80~84세  85~89세  90~94세  \
# 행정기관
# 전국         1,133,757  886,144  713,163  433,883  192,497  77,030  22,523
# 서울특별시        239,941  190,828  137,206   73,276   31,869  13,210   4,590
# 부산광역시        100,024   73,809   54,415   29,464   12,090   4,289   1,107
# 대구광역시         57,837   41,038   32,751   19,739    8,012   2,882     713
# 인천광역시         55,093   41,327   30,121   17,831    8,166   3,477   1,181
# 광주광역시         29,279   22,438   16,705    9,559    4,483   1,677     395
# 대전광역시         30,372   22,112   16,712   10,109    4,594   1,887     564
# 울산광역시         23,180   14,527    9,892    5,266    2,118     706     221
# 경기도          213,887  169,959  134,662   82,124   36,297  15,111   4,731
# 강원도           34,112   34,321   30,923   17,464    7,859   3,804   1,156
# 충청북도          33,957   29,310   26,284   17,415    7,301   3,143     871
# 충청남도          51,164   41,024   38,221   29,219   12,915   5,070   1,354
# 전라북도          49,971   39,293   34,601   24,213   11,648   4,320   1,101
# 전라남도          55,004   45,547   43,453   27,338   13,494   5,157   1,241
# 경상북도          72,382   55,201   51,673   35,179   15,860   6,434   1,783
# 경상남도          74,959   54,674   46,877   30,208   13,875   5,138   1,266
# 제주특별자치도       12,595   10,736    8,667    5,479    1,916     725     249
#
#           95~99세 100세 이상
# 행정기관
# 전국         4,696   2,652
# 서울특별시      1,182     894
# 부산광역시        246     228
# 대구광역시        147      81
# 인천광역시        222     120
# 광주광역시         72      31
# 대전광역시        110      44
# 울산광역시         44      12
# 경기도          968     570
# 강원도          260     142
# 충청북도         202      73
# 충청남도         282     112
# 전라북도         204      78
# 전라남도         218      72
# 경상북도         304     113
# 경상남도         181      64
# 제주특별자치도       54      18
#
# [17 rows x 21 columns]

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int)
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         1198629  1218866  1635253  1882958  1688523  1811906  2053846
# 서울특별시      217,099  213,296  284,211  346,341  337,208  425,224  473,659
# 부산광역시       67,561   69,275  100,418  129,556  123,139  127,645  138,435
# 대구광역시       53,691   59,382   86,060  103,540   93,449   85,681   91,645
# 인천광역시       68,511   67,688   90,598  108,523   98,356  102,165  117,371
# 광주광역시       37,452   40,844   57,241   62,773   50,772   52,316   58,161
# 대전광역시       38,302   40,402   53,450   61,306   54,648   55,649   61,025
# 울산광역시       29,624   29,199   41,539   50,177   42,080   40,104   47,459
# 경기도        321,179  325,500  414,592  451,409  385,905  415,444  500,699
# 강원도         32,577   35,954   49,205   54,452   52,414   48,907   51,313
# 충청북도        37,908   38,307   51,790   59,062   51,740   54,093   58,016
# 충청남도        53,382   52,083   67,481   72,666   63,864   72,590   84,000
# 전라북도        41,950   45,016   62,239   70,059   61,036   59,883   64,044
# 전라남도        41,502   42,763   61,184   68,467   57,846   56,639   61,556
# 경상북도        59,550   59,406   81,571   94,579   90,768   89,105   97,370
# 경상남도        83,483   83,188  112,232  127,302  107,591  108,904  128,811
# 제주특별자치도     14,858   16,563   21,442   22,746   17,707   17,557   20,282
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# 전국         2157764  2341732  2176857  ...  1598548  1133757   886144   713163
# 서울특별시      454,415  461,689  413,722  ...  332,974  239,941  190,828  137,206
# 부산광역시      134,969  148,270  145,936  ...  136,690  100,024   73,809   54,415
# 대구광역시      100,241  114,841  110,084  ...   80,598   57,837   41,038   32,751
# 인천광역시      122,844  132,406  130,257  ...   85,800   55,093   41,327   30,121
# 광주광역시       62,284   66,526   59,552  ...   37,628   29,279   22,438   16,705
# 대전광역시       65,560   70,718   63,155  ...   45,301   30,372   22,112   16,712
# 울산광역시       47,402   55,091   56,022  ...   36,400   23,180   14,527    9,892
# 경기도        555,001  600,130  544,270  ...  336,376  213,887  169,959  134,662
# 강원도         58,903   67,704   65,189  ...   55,067   34,112   34,321   30,923
# 충청북도        62,856   70,200   66,106  ...   50,734   33,957   29,310   26,284
# 충청남도        86,540   93,890   85,424  ...   64,615   51,164   41,024   38,221
# 전라북도        71,807   80,286   75,378  ...   59,417   49,971   39,293   34,601
# 전라남도        69,362   81,564   80,780  ...   61,419   55,004   45,547   43,453
# 경상북도       103,218  116,161  112,974  ...   93,558   72,382   55,201   51,673
# 경상남도       138,323  154,797  142,562  ...  105,378   74,959   54,674   46,877
# 제주특별자치도     24,039   27,459   25,446  ...   16,593   12,595   10,736    8,667
#
#            75~79세  80~84세  85~89세 90~94세 95~99세 100세 이상
# 행정기관
# 전국         433883  192497   77030  22523   4696    2652
# 서울특별시      73,276  31,869  13,210  4,590  1,182     894
# 부산광역시      29,464  12,090   4,289  1,107    246     228
# 대구광역시      19,739   8,012   2,882    713    147      81
# 인천광역시      17,831   8,166   3,477  1,181    222     120
# 광주광역시       9,559   4,483   1,677    395     72      31
# 대전광역시      10,109   4,594   1,887    564    110      44
# 울산광역시       5,266   2,118     706    221     44      12
# 경기도        82,124  36,297  15,111  4,731    968     570
# 강원도        17,464   7,859   3,804  1,156    260     142
# 충청북도       17,415   7,301   3,143    871    202      73
# 충청남도       29,219  12,915   5,070  1,354    282     112
# 전라북도       24,213  11,648   4,320  1,101    204      78
# 전라남도       27,338  13,494   5,157  1,241    218      72
# 경상북도       35,179  15,860   6,434  1,783    304     113
# 경상남도       30,208  13,875   5,138  1,266    181      64
# 제주특별자치도     5,479   1,916     725    249     54      18
#
# [17 rows x 21 columns]

# %% [markdown]
# ### 여자 데이터

# %%
df_w = pd.read_excel('201112_201112_연령별인구현황_월간.xlsx', skiprows=3, index_col='행정기관',
                    usecols='B, AB:AV')
df_w
# Out:
# C:\devtools\python\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#               0~4세.1     5~9세.1   10~14세.1   15~19세.1   20~24세.1   25~29세.1  \
# 행정기관
# 전국         1,129,806  1,128,548  1,499,278  1,663,636  1,523,792  1,703,195
# 서울특별시        206,060    200,193    262,310    310,655    333,221    434,166
# 부산광역시         64,091     64,395     89,822    109,704    109,926    119,872
# 대구광역시         50,013     53,228     75,776     85,776     74,247     79,000
# 인천광역시         64,856     63,633     83,927     98,468     91,310     96,656
# 광주광역시         35,011     37,506     53,033     57,115     47,178     50,777
# 대전광역시         36,082     37,416     49,187     53,905     48,597     52,972
# 울산광역시         27,460     26,137     36,777     41,072     33,601     35,734
# 경기도          303,944    304,545    385,154    408,993    362,452    395,085
# 강원도           30,481     33,018     45,107     48,620     41,983     40,494
# 충청북도          35,404     35,427     47,811     51,334     44,138     47,551
# 충청남도          50,155     48,363     62,308     65,002     58,485     62,031
# 전라북도          39,389     41,686     58,160     63,731     53,174     52,185
# 전라남도          39,253     39,670     56,425     61,408     48,742     47,898
# 경상북도          55,440     53,633     72,862     79,727     72,129     76,072
# 경상남도          78,184     74,997    100,946    107,759     88,715     96,312
# 제주특별자치도       13,983     14,701     19,673     20,367     15,894     16,390
#
#             30~34세.1   35~39세.1   40~44세.1   45~49세.1  ...   55~59세.1  \
# 행정기관                                                   ...
# 전국         1,970,608  2,072,568  2,275,390  2,052,704  ...  1,615,965
# 서울특별시        465,605    438,263    460,050    409,129  ...    359,313
# 부산광역시        132,335    130,836    152,337    148,810  ...    142,537
# 대구광역시         92,081    102,667    119,481    110,090  ...     84,873
# 인천광역시        111,247    116,704    131,460    124,852  ...     82,419
# 광주광역시         58,554     62,670     66,883     58,888  ...     39,698
# 대전광역시         60,987     65,212     71,342     61,723  ...     45,210
# 울산광역시         43,729     47,076     56,645     50,923  ...     33,896
# 경기도          490,170    542,585    584,184    499,306  ...    325,003
# 강원도           48,166     54,913     61,910     60,207  ...     54,308
# 충청북도          53,695     58,960     66,333     60,053  ...     49,761
# 충청남도          72,560     77,642     82,534     74,509  ...     64,076
# 전라북도          58,995     66,560     73,537     68,933  ...     59,407
# 전라남도          54,960     59,974     68,903     68,334  ...     59,715
# 경상북도          88,172     95,217    106,123    102,992  ...     95,014
# 경상남도         119,878    130,760    147,911    131,249  ...    104,076
# 제주특별자치도       19,474     22,529     25,757     22,706  ...     16,659
#
#             60~64세.1   65~69세.1 70~74세.1 75~79세.1 80~84세.1 85~89세.1 90~94세.1  \
# 행정기관
# 전국         1,185,550  1,011,421  927,668  696,462  425,984  206,395   72,491
# 서울특별시        258,378    205,191  158,189  107,363   67,032   34,398   12,901
# 부산광역시        105,268     79,853   68,053   46,756   28,568   13,063    4,090
# 대구광역시         62,558     48,419   44,223   31,774   18,329    8,196    2,763
# 인천광역시         54,816     45,728   39,713   30,024   18,924    9,357    3,216
# 광주광역시         32,111     25,357   22,133   15,850   10,171    4,926    1,916
# 대전광역시         30,825     24,726   21,363   16,370   10,020    4,859    1,657
# 울산광역시         21,248     15,106   12,752    9,426    6,054    3,081      953
# 경기도          223,180    195,104  172,731  127,069   76,688   38,088   13,375
# 강원도           37,000     39,658   38,997   27,676   17,752    8,961    3,195
# 충청북도          34,638     34,349   34,574   28,250   16,459    7,647    2,687
# 충청남도          52,444     48,254   51,254   44,117   25,218   12,252    4,240
# 전라북도          52,182     47,518   47,845   39,960   24,482   11,077    4,143
# 전라남도          56,206     56,282   62,998   48,220   30,823   14,512    5,133
# 경상북도          73,954     67,333   72,439   58,404   35,063   16,801    6,017
# 경상남도          77,562     66,659   68,890   55,439   34,398   15,820    4,635
# 제주특별자치도       13,180     11,884   11,514    9,764    6,003    3,357    1,570
#
#           95~99세.1 100세 이상.1
# 행정기관
# 전국          18,981     8,982
# 서울특별시        3,929     2,692
# 부산광역시        1,162       850
# 대구광역시          678       293
# 인천광역시          782       339
# 광주광역시          467       231
# 대전광역시          443       170
# 울산광역시          232        75
# 경기도          3,440     1,545
# 강원도            764       287
# 충청북도           693       215
# 충청남도         1,116       431
# 전라북도         1,033       403
# 전라남도         1,354       507
# 경상북도         1,377       405
# 경상남도         1,021       385
# 제주특별자치도        490       154
#
# [17 rows x 21 columns]

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns = df_m.columns # 컬럼명 통일

# %%
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int)

# %%
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국         1129806  1128548  1499278  1663636  1523792  1703195  1970608
# 서울특별시      206,060  200,193  262,310  310,655  333,221  434,166  465,605
# 부산광역시       64,091   64,395   89,822  109,704  109,926  119,872  132,335
# 대구광역시       50,013   53,228   75,776   85,776   74,247   79,000   92,081
# 인천광역시       64,856   63,633   83,927   98,468   91,310   96,656  111,247
# 광주광역시       35,011   37,506   53,033   57,115   47,178   50,777   58,554
# 대전광역시       36,082   37,416   49,187   53,905   48,597   52,972   60,987
# 울산광역시       27,460   26,137   36,777   41,072   33,601   35,734   43,729
# 경기도        303,944  304,545  385,154  408,993  362,452  395,085  490,170
# 강원도         30,481   33,018   45,107   48,620   41,983   40,494   48,166
# 충청북도        35,404   35,427   47,811   51,334   44,138   47,551   53,695
# 충청남도        50,155   48,363   62,308   65,002   58,485   62,031   72,560
# 전라북도        39,389   41,686   58,160   63,731   53,174   52,185   58,995
# 전라남도        39,253   39,670   56,425   61,408   48,742   47,898   54,960
# 경상북도        55,440   53,633   72,862   79,727   72,129   76,072   88,172
# 경상남도        78,184   74,997  100,946  107,759   88,715   96,312  119,878
# 제주특별자치도     13,983   14,701   19,673   20,367   15,894   16,390   19,474
#
#             35~39세   40~44세   45~49세  ...   55~59세   60~64세   65~69세   70~74세  \
# 행정기관                                  ...
# 전국         2072568  2275390  2052704  ...  1615965  1185550  1011421   927668
# 서울특별시      438,263  460,050  409,129  ...  359,313  258,378  205,191  158,189
# 부산광역시      130,836  152,337  148,810  ...  142,537  105,268   79,853   68,053
# 대구광역시      102,667  119,481  110,090  ...   84,873   62,558   48,419   44,223
# 인천광역시      116,704  131,460  124,852  ...   82,419   54,816   45,728   39,713
# 광주광역시       62,670   66,883   58,888  ...   39,698   32,111   25,357   22,133
# 대전광역시       65,212   71,342   61,723  ...   45,210   30,825   24,726   21,363
# 울산광역시       47,076   56,645   50,923  ...   33,896   21,248   15,106   12,752
# 경기도        542,585  584,184  499,306  ...  325,003  223,180  195,104  172,731
# 강원도         54,913   61,910   60,207  ...   54,308   37,000   39,658   38,997
# 충청북도        58,960   66,333   60,053  ...   49,761   34,638   34,349   34,574
# 충청남도        77,642   82,534   74,509  ...   64,076   52,444   48,254   51,254
# 전라북도        66,560   73,537   68,933  ...   59,407   52,182   47,518   47,845
# 전라남도        59,974   68,903   68,334  ...   59,715   56,206   56,282   62,998
# 경상북도        95,217  106,123  102,992  ...   95,014   73,954   67,333   72,439
# 경상남도       130,760  147,911  131,249  ...  104,076   77,562   66,659   68,890
# 제주특별자치도     22,529   25,757   22,706  ...   16,659   13,180   11,884   11,514
#
#             75~79세  80~84세  85~89세  90~94세 95~99세 100세 이상
# 행정기관
# 전국          696462  425984  206395   72491  18981    8982
# 서울특별시      107,363  67,032  34,398  12,901  3,929   2,692
# 부산광역시       46,756  28,568  13,063   4,090  1,162     850
# 대구광역시       31,774  18,329   8,196   2,763    678     293
# 인천광역시       30,024  18,924   9,357   3,216    782     339
# 광주광역시       15,850  10,171   4,926   1,916    467     231
# 대전광역시       16,370  10,020   4,859   1,657    443     170
# 울산광역시        9,426   6,054   3,081     953    232      75
# 경기도        127,069  76,688  38,088  13,375  3,440   1,545
# 강원도         27,676  17,752   8,961   3,195    764     287
# 충청북도        28,250  16,459   7,647   2,687    693     215
# 충청남도        44,117  25,218  12,252   4,240  1,116     431
# 전라북도        39,960  24,482  11,077   4,143  1,033     403
# 전라남도        48,220  30,823  14,512   5,133  1,354     507
# 경상북도        58,404  35,063  16,801   6,017  1,377     405
# 경상남도        55,439  34,398  15,820   4,635  1,021     385
# 제주특별자치도      9,764   6,003   3,357   1,570    490     154
#
# [17 rows x 21 columns]

# %% [markdown]
# ### 데이터 시각화

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# 한글 폰트 설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # 윈도우 전용
matplotlib.rcParams['font.size'] = 15 #폰트 크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(10, 7))
plt.barh(df_m.columns, -df_m.iloc[0] // 1000, label='남자') # 단위 천명 기준
plt.barh(df_w.columns, df_w.iloc[0] // 1000, label='여자') 
plt.title('2011 대한민국 인구 피라미드')
plt.savefig('2011_인구피라미드.png', dpi=100)
plt.legend();
